# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\moizr\Downloads\Netflix.csv")
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data.shape[0]
# Out:
# 7789

# %%
(data.isnull().sum()/data.shape[0])*100
# Out:
# Show_Id          0.000000
# Category         0.000000
# Title            0.000000
# Director        30.658621
# Cast             9.218128
# Country          6.509180
# Release_Date     0.128386
# Rating           0.089870
# Duration         0.000000
# Type             0.000000
# Description      0.000000
# dtype: float64

# %%
data.dropna(inplace=True)

# %% [markdown]
# # for data cleaning task split col

# %%
# x=data['Category'][0]
# x[:x.index(" ")]

# %%
def dura(x):
    return x[:x.index(" ")]

# %%
data['Duration'].apply(dura)
# Out:
# 1        93
# 2        78
# 3        80
# 4       123
# 5         1
#        ...
# 7780     88
# 7782     94
# 7783     88
# 7784     99
# 7785    111
# Name: Duration, Length: 4811, dtype: object

# %%
data['dura']=data['Duration'].apply(dura)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description dura
# 1  After a devastating earthquake hits Mexico Cit...   93
# 2  When an army recruit is found dead, his fellow...   78

# %%
def Description(u):
    return u[u.index(" ")+1:]

# %%
# data['Description'].apply[Description]
data['Description'].apply(Description)
# Out:
# 1       a devastating earthquake hits Mexico City, tra...
# 2       an army recruit is found dead, his fellow sold...
# 3       a postapocalyptic world, rag-doll robots hide ...
# 4       brilliant group of students become card-counti...
# 5       genetics professor experiments with a treatmen...
#                               ...
# 7780    to survive in a world taken over by zombies, a...
# 7782    drug dealer starts having doubts about his tra...
# 7783    from civilian life, a former superhero must tr...
# 7784    Lebanon's Civil War deprives Zozo of his famil...
# 7785    scrappy but poor boy worms his way into a tyco...
# Name: Description, Length: 4811, dtype: object

# %%
dataset=pd.read_csv(r"C:\Users\moizr\Downloads\CAR DETAILS FROM CAR DEKHO.csv")
dataset.head(2)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
#
#   seller_type transmission        owner
# 0  Individual       Manual  First Owner
# 1  Individual       Manual  First Owner

# %%
def name2(x):
    return x[:x.index(" ")]

# %%
def name(x):
    return x[x.index(" ")+1:]

# %%
dataset['name2']=dataset['name'].apply(name2)

# %%
dataset['name']=dataset['name'].apply(name)

# %%
dataset
# Out:
#                              name  year  selling_price  km_driven    fuel  \
# 0                          800 AC  2007          60000      70000  Petrol
# 1               Wagon R LXI Minor  2007         135000      50000  Petrol
# 2                    Verna 1.6 SX  2012         600000     100000  Diesel
# 3                 RediGO T Option  2017         250000      46000  Petrol
# 4                 Amaze VX i-DTEC  2014         450000     141000  Diesel
# ...                           ...   ...            ...        ...     ...
# 4335  i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000  Diesel
# 4336           i20 Magna 1.4 CRDi  2014         409999      80000  Diesel
# 4337                 800 AC BSIII  2009         110000      83000  Petrol
# 4338     Creta 1.6 CRDi SX Option  2016         865000      90000  Diesel
# 4339                     KWID RXT  2016         225000      40000  Petrol
#
#      seller_type transmission         owner    name2
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                              name  year  selling_price  km_driven    fuel  \
# 0                          800 AC  2007          60000      70000  Petrol
# 1               Wagon R LXI Minor  2007         135000      50000  Petrol
# 2                    Verna 1.6 SX  2012         600000     100000  Diesel
# 3                 RediGO T Option  2017         250000      46000  Petrol
# 4                 Amaze VX i-DTEC  2014         450000     141000  Diesel
# ...                           ...   ...            ...        ...     ...
# 4335  i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000  Diesel
# 4336           i20 Magna 1.4 CRDi  2014         409999      80000  Diesel
# 4337                 800 AC BSIII  2009         110000      83000  Petrol
# 4338     Creta 1.6 CRDi SX Option  2016         865000      90000  Diesel
# 4339                     KWID RXT  2016         225000      40000  Petrol
#
# ...

# %%
dataset.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# name2            0
# dtype: int64

# %%
dataset.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# name2            object
# dtype: object

# %% [markdown]
# #for removing comma in price

# %% [markdown]
# # dataset['price']=dataset['price'].str.replace(",","")

# %% [markdown]
# # def ruppee_change(x):
# #     p=x.split(" ")
# #     try:
# #         if p[1]=='Lakh':
# #             return str(round(float(p[0]*100000,1)
# #         else if p[1]=='Crore':
# #             return str(round(float(p[0]*100000000,1)
# #     except:
# #         return x

# %% [markdown]
# ##dataset['price']=dataset['price'].apply(ruppee_change)

# %%
# for change datatype
dataset['selling_price']=dataset['selling_price'].astype('float')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   float64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
#  8   name2          4340 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 305.3+ KB

# %% [markdown]
# # remove owner

# %%
dataset['owner']=dataset['owner'].str.replace(" Owner","")

# %%
dataset.head(2)
# Out:
#                 name  year  selling_price  km_driven    fuel seller_type  \
# 0             800 AC  2007        60000.0      70000  Petrol  Individual
# 1  Wagon R LXI Minor  2007       135000.0      50000  Petrol  Individual
#
#   transmission  owner   name2
# 0       Manual  First  Maruti
# 1       Manual  First  Maruti

# %% [markdown]
# # date time format netflix dataset

# %%
data['Release_Date']=pd.to_datetime(data['Release_Date'].str.strip())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4811 entries, 1 to 7785
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       4811 non-null   object
#  1   Category      4811 non-null   object
#  2   Title         4811 non-null   object
#  3   Director      4811 non-null   object
#  4   Cast          4811 non-null   object
#  5   Country       4811 non-null   object
#  6   Release_Date  4811 non-null   datetime64[ns]
#  7   Rating        4811 non-null   object
#  8   Duration      4811 non-null   object
#  9   Type          4811 non-null   object
#  10  Description   4811 non-null   object
#  11  dura          4811 non-null   object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 488.6+ KB

# %%
data.dropna()
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
# from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
category_en=LabelEncoder()

# %%
data['Category']=category_en.fit_transform(data['Category'])

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 1      s2         0  07:19  Jorge Michel Grau
# 2      s3         0  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description dura
# 1  After a devastating earthquake hits Mexico Cit...   93
# 2  When an army recruit is found dead, his fellow...   78

# %%
data['year']=data['Release_Date'].dt.year

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 1      s2         0  07:19  Jorge Michel Grau
# 2      s3         0  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description dura  year
# 1  After a devastating earthquake hits Mexico Cit...   93  2016
# 2  When an army recruit is found dead, his fellow...   78  2018

# %%
data.drop(columns=["Release_Date"])
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # outliers

# %%
plt.figure(figsize=(3,4))
sns.boxplot(x="selling_price",data=dataset)
plt.show()

# %%
q1=np.quantile(dataset['selling_price'],0.25)
q3=np.quantile(dataset['selling_price'],0.75)
q3,q1
# Out:
# (600000.0, 208749.75)

# %%
iqr=q3-q1
iqr
# Out:
# 391250.25

# %%
min_r=q1-(1.5*iqr)
max_r=q3+(1.5*iqr)
min_r,max_r
# Out:
# (-378125.625, 1186875.375)

# %%
dataset[dataset['selling_price']<=max_r]
# Out:
#                              name  year  selling_price  km_driven    fuel  \
# 0                          800 AC  2007        60000.0      70000  Petrol
# 1               Wagon R LXI Minor  2007       135000.0      50000  Petrol
# 2                    Verna 1.6 SX  2012       600000.0     100000  Diesel
# 3                 RediGO T Option  2017       250000.0      46000  Petrol
# 4                 Amaze VX i-DTEC  2014       450000.0     141000  Diesel
# ...                           ...   ...            ...        ...     ...
# 4335  i20 Magna 1.4 CRDi (Diesel)  2014       409999.0      80000  Diesel
# 4336           i20 Magna 1.4 CRDi  2014       409999.0      80000  Diesel
# 4337                 800 AC BSIII  2009       110000.0      83000  Petrol
# 4338     Creta 1.6 CRDi SX Option  2016       865000.0      90000  Diesel
# 4339                     KWID RXT  2016       225000.0      40000  Petrol
#
#      seller_type transmission   owner    name2
# ...

# %%
ss=StandardScaler()
newdata = pd.DataFrame(ss.fit_transform(dataset), columns=dataset.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16564\3281794430.py in ?()
#       1 ss=StandardScaler()
# ----> 2 newdata = pd.DataFrame(ss.fit_transform(dataset), columns=dataset.columns)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     874         # non-optimized default implementation; override when a better
#     875         # method is possible for a given clustering algorithm
#     876         if y is None:
# ...
